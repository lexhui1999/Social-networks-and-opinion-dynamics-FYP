# %%
import glob
import json
import pandas as pd
import numpy as np
import re
from datetime import datetime
import matplotlib.pyplot as plt

# %%
import warnings
import os
warnings.filterwarnings('ignore') # ignore deprecation warnings

# %%
def clean_mentions(x):
    x = re.sub(r'\w*@\w*', '', x)
    return x

# %%
tweets_dict = {}

# Read every *.jsons file in the ./tweet_jsons/ directory and copy them into a pandas dataframe
for filepath in glob.iglob('./tweet_jsons_initial/*.json'):
    tweets_df = pd.read_json(filepath, lines=True)
        
    if not tweets_df.empty:
        tweets_df["content"] = tweets_df["content"].astype(str)
        tweets_df["content"] = tweets_df["content"].apply(clean_mentions)
    
    tweets_dict[filepath[22:-13]] = tweets_df
    
print(list(tweets_dict.keys()))
# Out:
# ['barrysilbert', 'erikvoorhees', 'mskvsk', 'michael_saylor', 'Nickszabo4']

# %%
nodes = sorted(list(tweets_dict.keys()), key=str.casefold)
print(nodes)
# Out:
# ['barrysilbert', 'erikvoorhees', 'michael_saylor', 'mskvsk', 'Nickszabo4']

# %%
len(nodes)
# Out:
# 5

# %%
#Keyword filtering: only retain tweets related to cryptocurrency and remove empty lists

keywords = ["btc", "bitcoin", "XBT", "satoshi"]

for key in list(tweets_dict.keys()):
    #print(tweets_dict[key])
    if not tweets_dict[key].empty:
        tweets_dict[key] = tweets_dict[key][tweets_dict[key]["content"].str.contains('|'.join(keywords), na = False, case = False)]
    if tweets_dict[key].empty:
        del tweets_dict[key]

# %%
# %store nodes
# %store tweets_dict
# Out:
# Stored 'nodes' (list)
# Stored 'tweets_dict' (dict)

# %%
tweets_dict['barrysilbert'].head()
# Out:
#                                                   url  \
# 1   https://twitter.com/BarrySilbert/status/129908...
# 3   https://twitter.com/BarrySilbert/status/129901...
# 4   https://twitter.com/BarrySilbert/status/129897...
# 6   https://twitter.com/BarrySilbert/status/129897...
# 17  https://twitter.com/BarrySilbert/status/129394...
#
#                         date  \
# 1  2020-08-27 20:34:31+00:00
# 3  2020-08-27 15:56:35+00:00
# 4  2020-08-27 13:15:01+00:00
# 6  2020-08-27 13:09:58+00:00
# 17 2020-08-13 16:18:48+00:00
#
#                                               content  \
# 1   Digital Currency Group Enters the Bitcoin Mini...
# 3     it would be a high class problem for us if a...
# 4   There’s (digital) gold in them thar hills: Cry...
# 6   Unveiling our 4th subsidiary, Foundry, a bitco...
# 17  Interest in Grayscale Crypto Products Not Easi...
#
#                                       renderedContent                   id  \
# 1   Digital Currency Group Enters the Bitcoin Mini...  1299082889968132099
# 3   @adam3us @100trillionUSD it would be a high cl...  1299012944928419840
# 4   There’s (digital) gold in them thar hills: Cry...  1298972285680877573
# 6   Unveiling our 4th subsidiary, Foundry, a bitco...  1298971013821222912
# 17  Interest in Grayscale Crypto Products Not Easi...  1293945106937020417
#
#                                                  user  \
# 1   {'username': 'BarrySilbert', 'displayname': 'B...
# 3   {'username': 'BarrySilbert', 'displayname': 'B...
# 4   {'username': 'BarrySilbert', 'displayname': 'B...
# 6   {'username': 'BarrySilbert', 'displayname': 'B...
# 17  {'username': 'BarrySilbert', 'displayname': 'B...
#
#                                              outlinks  \
# 1   [https://decrypt.co/39953/digital-currency-gro...
# 3                                                  []
# 4   [https://fortune.com/2020/08/27/bitcoin-mining...
# 6   [https://twitter.com/DCGco/status/129897037301...
# 17  [https://cointelegraph.com/news/interest-in-gr...
#
#                   tcooutlinks  replyCount  retweetCount  ...  lang  \
# 1   [https://t.co/jhK2aDCMwZ]          25            94  ...    en
# 3                          []           7            12  ...    en
# 4   [https://t.co/JpnhHR2KKv]          13            71  ...    en
# 6   [https://t.co/NJzfJdKNv1]          63           130  ...    en
# 17  [https://t.co/6eq91DVeJx]          20            57  ...    en
#
#                                                source  \
# 1   <a href="https://mobile.twitter.com" rel="nofo...
# 3   <a href="http://twitter.com/download/iphone" r...
# 4   <a href="https://mobile.twitter.com" rel="nofo...
# 6   <a href="https://mobile.twitter.com" rel="nofo...
# 17  <a href="https://mobile.twitter.com" rel="nofo...
#
#                              sourceUrl         sourceLabel media  \
# 1           https://mobile.twitter.com     Twitter Web App  None
# 3   http://twitter.com/download/iphone  Twitter for iPhone  None
# 4           https://mobile.twitter.com     Twitter Web App  None
# 6           https://mobile.twitter.com     Twitter Web App  None
# 17          https://mobile.twitter.com     Twitter Web App  None
#
#    retweetedTweet                                        quotedTweet  \
# 1             NaN                                               None
# 3             NaN                                               None
# 4             NaN                                               None
# 6             NaN  {'url': 'https://twitter.com/DCGco/status/1298...
# 17            NaN                                               None
#
#                                        mentionedUsers  coordinates place
# 1   [{'username': 'decryptmedia', 'displayname': '...          NaN   NaN
# 3   [{'username': 'adam3us', 'displayname': 'Adam ...          NaN   NaN
# 4   [{'username': 'FortuneMagazine', 'displayname'...          NaN   NaN
# 6                                                None          NaN   NaN
# 17  [{'username': 'Cointelegraph', 'displayname': ...          NaN   NaN
#
# [5 rows x 23 columns]

# %%
def clean(raw):
    """ Remove hyperlinks and markup """
    result = re.sub(r'http\S+', '', raw)
    result = re.sub('&gt;', "", result)
    result = re.sub('&#x27;', "'", result)
    result = re.sub('&quot;', '"', result)
    result = re.sub('&#x2F;', ' ', result)
    result = re.sub('<p>', ' ', result)
    result = re.sub('</i>', '', result)
    result = re.sub('&#62;', '', result)
    result = re.sub('<i>', ' ', result)
    result = re.sub('\n', '', result)
    result = result.strip()

    return result

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

def nltk(text):
    score = analyzer.polarity_scores(text)
    return score

# %%
from textblob import TextBlob
from textblob.sentiments import PatternAnalyzer # pattern analyzer is the defaultfrom textblob import TextBlob
from textblob.sentiments import NaiveBayesAnalyzer

def textblob(text):
    blob = TextBlob(text)
    return blob.sentiment

# %%
def date_to_week(date):
    week = date.isocalendar()[1]
    week = (week + 52 - 20) % 52
    return week

# %%
for name in nodes:
    data = tweets_dict[name]
    tweets = pd.DataFrame()
    tweets['date'] = data['date'].apply(lambda x: str(x)[:10])
    tweets['date'] = pd.to_datetime(tweets['date'])
    tweets['week'] = tweets['date'].apply(date_to_week)
    tweets['tweets'] = data['content']
    tweets['tweets'] = tweets['tweets'].astype(str)
    tweets['processed'] = tweets['tweets'].apply(clean)
    
    # nlp packages
    # tweets['flair'] = tweets['tweets'].apply(lambda x: flair(x))
    tweets['nltk'] = tweets['tweets'].apply(nltk)
    tweets['textblob'] = tweets['tweets'].apply(textblob)
    
    tweets['nltk-compound'] = tweets['nltk'].apply(lambda x: x['compound'])
    tweets['nltk-pos'] = tweets['nltk'].apply(lambda x: x['pos'])
    tweets['nltk-neg'] = tweets['nltk'].apply(lambda x: x['neg'])
    tweets['tb-polarity'] = tweets['textblob'].apply(lambda x: x[0])
    tweets['tb-subjectivity'] = tweets['textblob'].apply(lambda x: x[1])
    tweets = tweets.drop(columns = ['nltk', 'textblob'])
    tweets = tweets.iloc[::-1]
    
    # get everyone's initial opinion
    
    
    with open('processed_initial/{}.csv'.format(name + '_processed'),'w') as f:
        tweets.to_csv(f, index = False)

# %%
initial_op = pd.DataFrame(columns = ['name', 'opinion'])

# %%
for i, name in enumerate(nodes):
    data = pd.read_csv('processed_initial/{}.csv'.format(name + '_processed'))
    data = data.drop(columns = ['tweets', 'processed'])
    data = data.groupby('week').mean()
    initial_op.loc[i] = [name, data.iloc[-1]['nltk-compound']]

# %%
data
# Out:
#       nltk-compound  nltk-pos  nltk-neg  tb-polarity  tb-subjectivity
# week
# 10         0.614433  0.129000  0.000000     0.217323         0.604040
# 11         0.294200  0.318000  0.000000     0.000000         0.000000
# 12         0.035550  0.069500  0.055000     0.214286         0.578571
# 13        -0.361200  0.000000  0.185000     0.080000         0.320000
# 14        -0.053500  0.157667  0.213333    -0.034444         0.507963
# 15         0.000000  0.000000  0.000000    -0.026786         0.126786

# %%
initial_op.to_csv('initial_na.csv', index = False)

# %%
initial_op
# Out:
#              name  opinion
# 0    barrysilbert   0.0460
# 1    erikvoorhees   0.4658
# 2  michael_saylor   0.6124
# 3          mskvsk   0.3400
# 4      Nickszabo4   0.0000
