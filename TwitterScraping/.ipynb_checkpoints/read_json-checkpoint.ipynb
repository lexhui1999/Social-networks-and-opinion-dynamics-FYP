# %%
import glob
import json
import pandas as pd

# %%
tweets_dict = {}

# Read every *.jsons file in the ./tweet_jsons/ directory and copy them into a pandas dataframe
for filepath in glob.iglob('./tweet_jsons/*.json'):
    f = open(filepath, "r")
    tweets_df = pd.read_json(filepath, lines=True)
    tweets_dict[filepath[14:-5]] = tweets_df
    
print(tweets_dict.keys())
# Out:
# dict_keys(['SatoshiLite', 'Crypto_goat_', 'gavinandresen', 'cryptodemedici', 'justinsuntron', 'VentureCoinist', 'aantonop', 'charlieshrem', 'notsofast', 'cryptopathic', 'rogerkver', 'barrysilbert', 'needacoin', 'jimmysong', '6BillionPeople', 'crypto_God', 'cryptobanger', 'APompliano', 'lopp', 'thecryptomofo', 'tuurdemeester', 'CryptoChoe', 'onemanatatime', 'WhalePanda', 'CryptoCobain', 'DiaryofaMademan', 'CryptoTutor', 'peterlbrandt', 'ToneVays', 'Thecryptodog', 'VitalikButerin', 'VinnyLingham', '22loops', 'erikvoorhees', 'balajis', 'cryptogat', 'IOHK_Charles', 'PhilakoneCrypt', 'IOTA_Charles', 'IAMJOSEPHYYOUNG', 'crypto_rand', 'CryptoYoda1338', 'NicTrades', 'legendofcrypto', 'cz_binance', 'CremeDeLaCrypto', 'secretsofcrypto', 'CryptoHustle', 'officialmcafee', 'cryptomocho', 'pmarca', 'brian_armstrong', 'novogratz', 'nickszabo4', 'angelabtc', 'ZeusZissou', 'cryptoBully', 'CryptoOrca'])

# %%
#Keyword filtering: only retain tweets related to cryptocurrency and remove empty lists

keywords = ["btc", "ethereum", "coin", "crypto", "hodl"]

for key in list(tweets_dict.keys()):
    #print(tweets_dict[key])
    if not tweets_dict[key].empty:
        tweets_dict[key] = tweets_dict[key][tweets_dict[key]["content"].str.contains('|'.join(keywords), na = False, case = False)]
    if tweets_dict[key].empty:
        del tweets_dict[key]

# %%
print(tweets_dict.keys())
# Out:
# dict_keys(['novogratz', 'rogerkver', 'needacoin', 'crypto_rand', 'ToneVays', 'VitalikButerin', 'peterlbrandt', 'NicTrades', 'DiaryofaMademan', 'APompliano', 'lopp', 'nickszabo4', 'IOHK_Charles', 'CryptoCobain', '6BillionPeople', 'VinnyLingham', 'WhalePanda', 'cryptopathic', 'CryptoHustle', 'gavinandresen', 'Crypto_goat_', 'aantonop', 'brian_armstrong', 'cryptobanger', '22loops', 'CryptoYoda1338', 'VentureCoinist', 'secretsofcrypto', 'barrysilbert', 'Thecryptodog', 'onemanatatime', 'cryptomocho', 'officialmcafee', 'erikvoorhees', 'balajis', 'ZeusZissou', 'CremeDeLaCrypto', 'CryptoTutor', 'cz_binance', 'jimmysong', 'justinsuntron', 'notsofast', 'charlieshrem', 'SatoshiLite'])

# %%
tweets_dict['novogratz']
# Out:
#                                                     url  \
# 0     https://twitter.com/novogratz/status/138140748...
# 9     https://twitter.com/novogratz/status/138092317...
# 21    https://twitter.com/novogratz/status/138057150...
# 22    https://twitter.com/novogratz/status/138057084...
# 23    https://twitter.com/novogratz/status/138049249...
# ...                                                 ...
# 1418  https://twitter.com/novogratz/status/130129515...
# 1420  https://twitter.com/novogratz/status/130125991...
# 1421  https://twitter.com/novogratz/status/130112527...
# 1422  https://twitter.com/novogratz/status/130108880...
# 1423  https://twitter.com/novogratz/status/130084157...
#
#                           date  \
# 0    2021-04-12 00:43:03+00:00
# 9    2021-04-10 16:38:36+00:00
# 21   2021-04-09 17:21:12+00:00
# 22   2021-04-09 17:18:34+00:00
# 23   2021-04-09 12:07:13+00:00
# ...                        ...
# 1418 2020-09-02 23:05:15+00:00
# 1420 2020-09-02 20:45:13+00:00
# 1421 2020-09-02 11:50:14+00:00
# 1422 2020-09-02 09:25:18+00:00
# 1423 2020-09-01 17:02:54+00:00
#
#                                                 content  \
# 0     @jav555888 @SBF_Alameda @cz_binance Don’t be s...
# 9     @CryptoBeliever8 Because he was afraid he woul...
# 21     @Dr_HODLz @Bitclout_ Next week.  Been sooo busy.
# 22    Someone should meme the scene in anchorman 2 w...
# 23    @AMERICANHODL3 That is funny.  How’s the train...
# ...                                                 ...
# 1418  @ratemyskyperoom @cfed__ @intangiblecoins @ben...
# 1420  @RonPatiro @CNBC I’m not brushing it off it al...
# 1421  $btc reminding us that there is no free lunch....
# 1422  And we vote for another 74 year old 😢. I’m not...
# 1423  Trying to make sense of the frenzy we are in.....
#
#                                         renderedContent                   id  \
# 0     @jav555888 @SBF_Alameda @cz_binance Don’t be s...  1381407480945709057
# 9     @CryptoBeliever8 Because he was afraid he woul...  1380923176503406600
# 21     @Dr_HODLz @Bitclout_ Next week.  Been sooo busy.  1380571509383700482
# 22    Someone should meme the scene in anchorman 2 w...  1380570847514132481
# 23    @AMERICANHODL3 That is funny.  How’s the train...  1380492494656446467
# ...                                                 ...                  ...
# 1418  @ratemyskyperoom @cfed__ @intangiblecoins @ben...  1301295150312960003
# 1420  @RonPatiro @CNBC I’m not brushing it off it al...  1301259911033171970
# 1421  $btc reminding us that there is no free lunch....  1301125275380527104
# 1422  And we vote for another 74 year old 😢. I’m not...  1301088804737028102
# 1423  Trying to make sense of the frenzy we are in.....  1300841572884516866
#
#                                                    user  \
# 0     {'username': 'novogratz', 'displayname': 'Mike...
# 9     {'username': 'novogratz', 'displayname': 'Mike...
# 21    {'username': 'novogratz', 'displayname': 'Mike...
# 22    {'username': 'novogratz', 'displayname': 'Mike...
# 23    {'username': 'novogratz', 'displayname': 'Mike...
# ...                                                 ...
# 1418  {'username': 'novogratz', 'displayname': 'Mike...
# 1420  {'username': 'novogratz', 'displayname': 'Mike...
# 1421  {'username': 'novogratz', 'displayname': 'Mike...
# 1422  {'username': 'novogratz', 'displayname': 'Mike...
# 1423  {'username': 'novogratz', 'displayname': 'Mike...
#
#                                                outlinks  \
# 0                                                    []
# 9                                                    []
# 21                                                   []
# 22                                                   []
# 23                                                   []
# ...                                                 ...
# 1418                                                 []
# 1420                                                 []
# 1421                                                 []
# 1422  [https://twitter.com/GroundworkProj/status/130...
# 1423  [https://www.bnnbloomberg.ca/video/this-will-b...
#
#                     tcooutlinks  replyCount  retweetCount  ...  lang  \
# 0                            []           3             1  ...    en
# 9                            []          20             1  ...    en
# 21                           []           2             2  ...    en
# 22                           []          59            14  ...    en
# 23                           []           2             2  ...    en
# ...                         ...         ...           ...  ...   ...
# 1418                         []           1             2  ...    en
# 1420                         []           2             0  ...    en
# 1421                         []         131            26  ...    en
# 1422  [https://t.co/W8Srb5u5Y7]          10             3  ...    en
# 1423  [https://t.co/OxcO9n2CSb]           4            17  ...    en
#
#                                                  source  \
# 0     <a href="http://twitter.com/download/iphone" r...
# 9     <a href="http://twitter.com/download/iphone" r...
# 21    <a href="http://twitter.com/download/iphone" r...
# 22    <a href="http://twitter.com/download/iphone" r...
# 23    <a href="http://twitter.com/download/iphone" r...
# ...                                                 ...
# 1418  <a href="http://twitter.com/download/iphone" r...
# 1420  <a href="http://twitter.com/download/iphone" r...
# 1421  <a href="http://twitter.com/download/iphone" r...
# 1422  <a href="http://twitter.com/download/iphone" r...
# 1423  <a href="https://mobile.twitter.com" rel="nofo...
#
#                                sourceUrl         sourceLabel  \
# 0     http://twitter.com/download/iphone  Twitter for iPhone
# 9     http://twitter.com/download/iphone  Twitter for iPhone
# 21    http://twitter.com/download/iphone  Twitter for iPhone
# 22    http://twitter.com/download/iphone  Twitter for iPhone
# 23    http://twitter.com/download/iphone  Twitter for iPhone
# ...                                  ...                 ...
# 1418  http://twitter.com/download/iphone  Twitter for iPhone
# 1420  http://twitter.com/download/iphone  Twitter for iPhone
# 1421  http://twitter.com/download/iphone  Twitter for iPhone
# 1422  http://twitter.com/download/iphone  Twitter for iPhone
# 1423          https://mobile.twitter.com     Twitter Web App
#
#                                                   media retweetedTweet  \
# 0                                                  None            NaN
# 9                                                  None            NaN
# 21                                                 None            NaN
# 22                                                 None            NaN
# 23                                                 None            NaN
# ...                                                 ...            ...
# 1418  [{'previewUrl': 'https://pbs.twimg.com/media/E...            NaN
# 1420                                               None            NaN
# 1421                                               None            NaN
# 1422                                               None            NaN
# 1423                                               None            NaN
#
#                                             quotedTweet  \
# 0                                                  None
# 9                                                  None
# 21                                                 None
# 22                                                 None
# 23                                                 None
# ...                                                 ...
# 1418                                               None
# 1420                                               None
# 1421                                               None
# 1422  {'url': 'https://twitter.com/GroundworkProj/st...
# 1423                                               None
#
#                                          mentionedUsers  coordinates place
# 0     [{'username': 'jav555888', 'displayname': 'Jav...          NaN   NaN
# 9     [{'username': 'CryptoBeliever8', 'displayname'...          NaN   NaN
# 21    [{'username': 'Dr_HODLz', 'displayname': 'elco...          NaN   NaN
# 22                                                 None          NaN   NaN
# 23    [{'username': 'AMERICANHODL3', 'displayname': ...          NaN   NaN
# ...                                                 ...          ...   ...
# 1418  [{'username': 'ratemyskyperoom', 'displayname'...          NaN   NaN
# 1420  [{'username': 'RonPatiro', 'displayname': 'Ron...          NaN   NaN
# 1421                                               None          NaN   NaN
# 1422  [{'username': 'joekennedy', 'displayname': 'Jo...          NaN   NaN
# 1423                                               None          NaN   NaN
#
# [316 rows x 23 columns]
